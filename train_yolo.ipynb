# %%
from ultralytics import YOLO
import sys
import subprocess

subprocess.check_call([sys.executable, "-m", "pip", "install", "torch", "torchvision", "torchaudio", "--index-url", "https://download.pytorch.org/whl/cu121", "--force-reinstall"])
model = YOLO('yolov8n.pt')

model.train(
    data='C:\\work\\sms2i\\sms2i-ai\\dataset\\dataset.yaml',
    epochs=150,           # Give it a bit more room to learn all variations
    imgsz=640,
    
    # --- Geometric & Spatial Augmentations ---
    fliplr=0.5,           # 50% chance to mirror horizontally
    flipud=0.5,           # 50% chance to flip upside down (if applicable to your objects)
    degrees=45.0,         # Heavy rotation (up to 45 degrees left or right)
    scale=0.7,            # Aggressive scaling (zooming in and out drastically)
    shear=10.0,           # Shear distortion to warp shapes from different angles
    perspective=0.0005,   # Adds slight 3D perspective distortion (depth simulation)
    
    # --- Color & Lighting Augmentations ---
    hsv_h=0.015,          # Hue variation (shifts the color tint slightly)
    hsv_s=0.7,            # Saturation variation (makes colors punchier or washed out)
    hsv_v=0.4,            # Value variation (simulates bright lights vs. dim shadows)
    
    # --- Regularization & Mixes ---
    mosaic=1.0,           # Stitches 4 training images together into a single grid (essential for small datasets)
    mixup=0.15,           # Blends two different images and their bounding boxes together
    copy_paste=0.1,       # Copies objects from one image and pastes them onto another
    workers=4,
    device=0,
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.103 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.90  Python-3.11.9 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1650 with Max-Q Design, 4096MiB)
# ...
